# %% [markdown]
# <a href="https://colab.research.google.com/github/Chansikan/Python-tutorial/blob/master/pydicom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 35.5MB 1.4MB/s
# ...

# %%
import pydicom
import numpy as np
import os
import shutil

# %%
srcDir = '/content/drive/My Drive/Colab Notebooks/test_dcm'
destDir = '/content'

for case in os.listdir(srcDir):
  casePath = os.path.join(srcDir, case)

  for dcm in os.listdir(casePath):
    dcmPath = os.path.join(casePath, dcm)
    dcmData = pydicom.dcmread(filePath)
    Pt_ID = dcmData[0x00100020].value
    Series_name = dcmData[0x0008103e].value

    dcmDestDir = os.path.join(destDir, Pt_ID, Series_name)
    os.makedirs(dcmDestDir, exist_ok=True)
    dcmDestPath = os.path.join(destDir, Pt_ID, Series_name, dcm)
    shutil.copyfile(dcmPath, dcmDestPath)

# %%
dcmData
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 184
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113619.2.340.3.314590742.548.1527836673.601.17
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.10.6'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20180601'
# (0008, 0013) Instance Creation Time              TM: '105117'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# ...
